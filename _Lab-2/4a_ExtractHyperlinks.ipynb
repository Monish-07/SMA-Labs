# %%
import requests
from bs4 import BeautifulSoup

def extract_hyperlinks(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    hyperlinks = []
    for link in soup.find_all('a'):
        hyperlink = link.get('href')
        if hyperlink:
            hyperlinks.append(hyperlink)
    
    return hyperlinks

# Example usage
webpage_url = 'https://www.espncricinfo.com/'
hyperlinks = extract_hyperlinks(webpage_url)
print("Hyperlinks found on the webpage:")
for hyperlink in hyperlinks:
    print(hyperlink)

# %%
import requests
from bs4 import BeautifulSoup

# %%
def extract_hyperlinks(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    hyperlinks = []
    for link in soup.find_all('a'):
        hyperlink = link.get('href')
        if hyperlink:
            hyperlinks.append(hyperlink)
    
    return hyperlinks

# %%
# Example usage
webpage_url = 'https://www.espncricinfo.com/'
hyperlinks = extract_hyperlinks(webpage_url)
print("Hyperlinks found on the webpage:")
for hyperlink in hyperlinks:
    print(hyperlink)
# Out:
# Hyperlinks found on the webpage:
# /series/afghanistan-in-bangladesh-2023-1377001/bangladesh-vs-afghanistan-only-test-1377011/live-cricket-score
# /series/afghanistan-in-bangladesh-2023-1377001/match-schedule-fixtures-and-results
# /series/afghanistan-in-bangladesh-2023-1377001/bangladesh-vs-afghanistan-only-test-1377011/match-report
# /series/afghanistan-in-bangladesh-2023-1377001
# /series/tnpl-2023-1379595/siechem-madurai-panthers-vs-nellai-royal-kings-3rd-match-1379598/live-cricket-score
# /series/tnpl-2023-1379595/match-schedule-fixtures-and-results
# /series/tnpl-2023-1379595/siechem-madurai-panthers-vs-nellai-royal-kings-3rd-match-1379598/points-table-standings
# /series/tnpl-2023-1379595
# /series/south-africa-a-in-sri-lanka-2023-1379628/sri-lanka-a-vs-south-africa-a-1st-unofficial-test-1379634/live-cricket-score
# /series/south-africa-a-in-sri-lanka-2023-1379628/match-schedule-fixtures-and-results
# /series/south-africa-a-in-sri-lanka-2023-1379628
# ...
